# %% [markdown]
# # Análise de dados
# import pandas as pd
# import numpy as np
# import os
#
# # Gráficos
# import matplotlib.pyplot as plt
#
# pasta_notebook = "../scr"
# caminho = os.
# df = pd.read_csv(url)

# %%
# Análise de dados
import pandas as pd
import numpy as np

# Gráficos
import matplotlib.pyplot as plt


path = "https://raw.githubusercontent.com/squad-ada-lovelace/Desafio_07-Desafio-final/refs/heads/main/src/Sleep_health_and_lifestyle_dataset.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
traducao_colunas = ['ID da pessoa', 'genero', 'idade', 'ocupacao', 'duracao do sono', 'qualidade do sono', 'tempo diario de atividade fisica', 'nivel de estresse',
                    'classificacao do IMC', 'pressao sanguinea', 'batimentos cardiacos','passos diarios', 'transtorno do sono']
colunas = df.columns

df = df.rename(columns=dict(zip(colunas, traducao_colunas)))

df
# Out:
#      ID da pessoa  genero  idade              ocupacao  duracao do sono  \
# 0               1    Male     27     Software Engineer              6.1
# 1               2    Male     28                Doctor              6.2
# 2               3    Male     28                Doctor              6.2
# 3               4    Male     28  Sales Representative              5.9
# 4               5    Male     28  Sales Representative              5.9
# ..            ...     ...    ...                   ...              ...
# 369           370  Female     59                 Nurse              8.1
# 370           371  Female     59                 Nurse              8.0
# 371           372  Female     59                 Nurse              8.1
# 372           373  Female     59                 Nurse              8.1
# 373           374  Female     59                 Nurse              8.1
#
#      qualidade do sono  tempo diario de atividade fisica  nivel de estresse  \
# ...

# %%
#traduzindo possíveis respostas de gênero
traducao_genero ={
    'Male': 'masculino',
    'Female': 'feminino'}

df['genero'] = df['genero'].map(traducao_genero)

df
# Out:
#      ID da pessoa     genero  idade              ocupacao  duracao do sono  \
# 0               1  masculino     27     Software Engineer              6.1
# 1               2  masculino     28                Doctor              6.2
# 2               3  masculino     28                Doctor              6.2
# 3               4  masculino     28  Sales Representative              5.9
# 4               5  masculino     28  Sales Representative              5.9
# ..            ...        ...    ...                   ...              ...
# 369           370   feminino     59                 Nurse              8.1
# 370           371   feminino     59                 Nurse              8.0
# 371           372   feminino     59                 Nurse              8.1
# 372           373   feminino     59                 Nurse              8.1
# 373           374   feminino     59                 Nurse              8.1
#
# ...

# %%
#verificando possibilidades de ocupação
df['ocupacao'].unique()
# Out:
# array(['Software Engineer', 'Doctor', 'Sales Representative', 'Teacher',
#        'Nurse', 'Engineer', 'Accountant', 'Scientist', 'Lawyer',
#        'Salesperson', 'Manager'], dtype=object)

# %%
traducao_ocupacao = {
    'Nurse': 'enfermeiro(a)',
    'Doctor': 'medico(a)',
    'Engineer': 'engenheiro(a)',
    'Lawyer': 'advogado(a)',
    'Teacher': 'professor(a)',
    'Accountant': 'contador(a)',
    'Salesperson': 'vendedor(a)',
    'Scientist': 'cientista',
    'Software Engineer': 'engenheiro(a) de software',
    'Sales Representative': 'representante de vendas',
    'Manager': 'gerente'
}

df['ocupacao'] = df['ocupacao'].map(traducao_ocupacao)

df
# Out:
#      ID da pessoa     genero  idade                   ocupacao  \
# 0               1  masculino     27  engenheiro(a) de software
# 1               2  masculino     28                  medico(a)
# 2               3  masculino     28                  medico(a)
# 3               4  masculino     28    representante de vendas
# 4               5  masculino     28    representante de vendas
# ..            ...        ...    ...                        ...
# 369           370   feminino     59              enfermeiro(a)
# 370           371   feminino     59              enfermeiro(a)
# 371           372   feminino     59              enfermeiro(a)
# 372           373   feminino     59              enfermeiro(a)
# 373           374   feminino     59              enfermeiro(a)
#
#      duracao do sono  qualidade do sono  tempo diario de atividade fisica  \
# 0                6.1                  6                                42
# ...

# %%
df['ocupacao']
# Out:
# 0      engenheiro(a) de software
# 1                      medico(a)
# 2                      medico(a)
# 3        representante de vendas
# 4        representante de vendas
#                  ...
# 369                enfermeiro(a)
# 370                enfermeiro(a)
# 371                enfermeiro(a)
# 372                enfermeiro(a)
# 373                enfermeiro(a)
# Name: ocupacao, Length: 374, dtype: object
